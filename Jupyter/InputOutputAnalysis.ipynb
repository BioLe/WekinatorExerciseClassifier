# %%
import csv
import pandas as pd

# %%
dfInputs = pd.read_csv("PhoneInput_2018-11-06_16-21-07.csv")
dfInputs
# Out:
#       ElapsedTime  GravityX  GravityY  GravityZ   LinearX   LinearY   LinearZ
# 0        0.020000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1        0.040000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2        0.140000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 3        0.191000  1.066864  9.264427  3.033575 -1.135819 -0.137547 -0.453147
# 4        0.207964  1.066864  9.264427  3.033575 -1.135819 -0.137547 -0.453147
# 5        0.225430  1.066864  9.264427  3.033575 -1.135819 -0.137547 -0.453147
# 6        0.241664  1.066864  9.264427  3.033575 -1.135819 -0.137547 -0.453147
# 7        0.258513  1.066864  9.264427  3.033575 -1.135819 -0.137547 -0.453147
# 8        0.275402  1.066864  9.264427  3.033575 -1.135819 -0.137547 -0.453147
# 9        0.292211  1.066864  9.264427  3.033575 -1.135819 -0.137547 -0.453147
# 10       0.309423  1.066864  9.264427  3.033575 -1.135819 -0.137547 -0.453147
# ...

# %%
dfOutputs = pd.read_csv("WekinatorOutput_2018-11-06_16-21-07.csv")
dfOutputs = dfOutputs.astype(float)
dfOutputs[dfOutputs.columns[0]]
#dfOutputs
# Out:
# 0        0.020000
# 1        0.040000
# 2        0.140000
# 3        0.191000
# 4        0.207964
# 5        0.225430
# 6        0.241664
# 7        0.258513
# 8        0.275402
# 9        0.292211
# 10       0.309423
# 11       0.325910
# 12       0.343409
# 13       0.359608
# 14       0.376462
# 15       0.393491
# 16       0.410506
# 17       0.453540
# 18       0.497300
# 19       0.542000
# 20       0.558851
# 21       0.576395
# 22       0.592549
# 23       0.609402
# 24       0.626378
# 25       0.643444
# 26       0.660432
# 27       0.676859
# 28       0.693645
# 29       0.710495
#           ...
# 3956    67.433450
# 3957    67.450330
# 3958    67.467320
# 3959    67.484310
# 3960    67.501300
# 3961    67.518390
# 3962    67.534560
# 3963    67.552320
# 3964    67.568270
# 3965    67.596510
# 3966    67.613370
# 3967    67.630240
# 3968    67.647270
# 3969    67.664230
# 3970    67.681220
# 3971    67.698210
# 3972    67.715260
# 3973    67.731320
# 3974    67.750550
# ...

# %%
dfInputs.plot(x='ElapsedTime', y=dfInputs.columns[1:], figsize=(20,10))

# %%
dfInputs.plot(x='ElapsedTime', y=['GravityX', 'GravityY', 'GravityZ'], figsize=(20,10))

# %%
dfInputs.plot(x='ElapsedTime', y=['LinearX', 'LinearY', 'LinearZ'], figsize=(20,10))

# %%
dfOutputs.plot(x='ElapsedTime', y=dfOutputs.columns[1:4], figsize=(20,10))

# %%
dfOutputs.plot(x='ElapsedTime', y=['BestClass'], figsize=(20,10))
